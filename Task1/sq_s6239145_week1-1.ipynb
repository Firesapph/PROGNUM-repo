# %% [markdown]
# Answers for Week 1
#
# * Name: Saffira Arentsen
# * Username: sarentsen
# * Student s-number: s6239145
# * Group (AS1, etc.): AS2

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
x = 6
x *= 5
x *= 4
x *= 3
x *= 2
x *= 1
print(x)
# Out:
# 720

# %%
from scipy.constants import G
mass_moon = 7.342e22
mass_earth = 5.9722e24
r = 385000.6*1000
F = G*mass_moon*mass_earth/r**2
print(f'The gravitation pull between Earth and the moon is: {F}')
# Out:
# The gravitation pull between Earth and the moon is: 1.974384051807571e+20

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %%
a = 149598023e3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The screenshot above shows the file myfirst.py in both panels in filezilla. (Session quiz 1.10)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The dot in the command in the screenshot above makes sure it's the current directory. (Session quiz 1.11)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Above is the screenshot for sesson quiz 1.12

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The screenshot above is from FileZilla showing the file myfirst.py in both panels (session quiz 1.10)

# %% [markdown]
# Session quiz 1.15
# 1. The output of the Unix command pwd in the Downloads folder from the home directory will be: /Users/users/sarentsen/Downloads
# 2. A . indicates the current directory and .. indicates the parent directory.

# %% [markdown]
# Session quiz 1.16:
# The shortest command will be: cd ~/Desktop

# %% [markdown]
# Session quiz 1.19
# 1. The command ls *[0-9]*.[co] lists the files that contain a number between 0 and 9, a dot and then contains either a 'c' or an 'o'. So in this case the result is: t1.c  t1t.c  t2.o
# 2. The square brackets match a range of characters.
# 3. The difference is that the command ls *[0-9]*.co lists files ending on 'co', whereas the first command lists files ending on 'c' or 'o'.
